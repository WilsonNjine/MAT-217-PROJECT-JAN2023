# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive

# %%
data=pd.read_csv("/content/contentdrive/MyDrive/archive.zip")

# %%
data.head()
# Out:
#    Unnamed: 0  property_id  location_id  \
# 0           0       237062         3325
# 1           1       346905         3236
# 2           2       386513          764
# 3           3       656161          340
# 4           4       841645         3226
#
#                                             page_url property_type     price  \
# 0  https://www.zameen.com/Property/g_10_g_10_2_gr...          Flat  10000000
# 1  https://www.zameen.com/Property/e_11_2_service...          Flat   6900000
# 2  https://www.zameen.com/Property/islamabad_g_15...         House  16500000
# 3  https://www.zameen.com/Property/islamabad_bani...         House  43500000
# 4  https://www.zameen.com/Property/dha_valley_dha...         House   7000000
#
#       location       city      province_name   latitude  longitude  baths  \
# 0         G-10  Islamabad  Islamabad Capital  33.679890  73.012640      2
# 1         E-11  Islamabad  Islamabad Capital  33.700993  72.971492      3
# ...

# %%
data["bedrooms"].value_counts().plot(kind="bar")
plt.title("number of bedrooms")
plt.xlabel("Bedrooms")
plt.ylabel("Count")
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=data.latitude.values, y=data.longitude.values, size=10)
plt.ylabel("longitude" , fontsize=12)
plt.xlabel("latitude" , fontsize=12)
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(data.price,data.Total_Area)
plt.title("price vs square meters")
# Out:
# Text(0.5, 1.0, 'price vs square meters')

# %%
plt.scatter(data.price,data.longitude,data.latitude)
plt.title("price vs location of the area")
# Out:
# Text(0.5, 1.0, 'price vs location of the area')

# %%
plt.scatter(data.price,data.latitude)
plt.title("price vs location")
# Out:
# Text(0.5, 1.0, 'price vs location')

# %%
plt.scatter(data.bedrooms,data.price)
plt.title("bedroom vs price")
plt.xlabel("bedrooms")
plt.ylabel("price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(data.property_type,data.price)
plt.title("property type vs price")
# Out:
# Text(0.5, 1.0, 'property type vs price')

# %%
plt.scatter(data.baths,data.price)
plt.title("baths vs price")
# Out:
# Text(0.5, 1.0, 'baths vs price')

# %%
plt.scatter(data.location_id,data.price)
plt.title("Most pricey location")
# Out:
# Text(0.5, 1.0, 'Most pricey location')

# %%
plt.scatter(data.date_added,data.price)
plt.title("price vs age")
# Out:
# Text(0.5, 1.0, 'price vs age')

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
labels = data["price"]
conv_baths = [1 if values == 1 else 0 for values in data.baths]
data["baths"] = conv_baths
train1 = data.drop(["property_id", "price"],axis=1)

# %%
from sklearn.model_selection import train_test_split
